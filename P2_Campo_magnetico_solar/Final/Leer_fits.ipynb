# %%
from pylab import *
import pyfits
import scipy
from scipy.interpolate import griddata

# %%
datos = pyfits.open('hmi.m_45s.magnetogram.subregion_x1y1.fits')

# %%
cols = datos[0].data
print shape(cols) 
#test = cols[:,5,5]

x = linspace(0, 397, 398)
y = linspace(0, 198, 199)
z = linspace(0, 206, 207)

#plot(z, test)
#xlabel("coordenada temporal sin unidades")
#ylabel("Campo Magenitco [Gauss]")
# Out:
# (207, 199, 398)

# %%
#arreglo para el tiempo
tiempo=np.genfromtxt('times_delta.csv', delimiter=',')

#Arreglo del campo magnetico solar
campo = cols[:,33,66]

plot(tiempo, campo)
xlabel("coordenada temporal en segundos")
ylabel("Campo Magenitco [Gauss]")
plt.show()

# %%
#MCMC 

#funcion de likelihood lineal, sin exp
def likelihood(campo_m,y_m):
    chi_cuadrado= (1.0/2.0)*sum((campo_m-y_m)**2)
    a=(-chi_cuadrado)
    return a

#funcion de likelihood lineal gauss, sin exp
def likelihood_linealgauss(campo_m,y_m):
    chi_cuadrado= (1.0/2.0)*sum((campo_m-y_m)**2)
    a=(-chi_cuadrado)
    return a

#funcion de likelihood lineal paso, sin exp
def likelihood_linealpaso(campo_m,y_m):
    chi_cuadrado= (1.0/2.0)*sum((campo_m-y_m)**2)
    a=(-chi_cuadrado)
    return a


#funcion 1
def modelo_lineal(t_obs,a,b):
    return a + b*t_obs
#funcion 2

def lineal_gauss(t_obs,c,d,sig,nu):
    return c + d*t_obs + (1/(sig*sqrt(2*pi)))*np.exp(-(1/2)*((t_obs-nu)/sig)**2)
#funcion 3
def lineal_paso(t_obs, f, g, h, n, t0):
    return f + g*t_obs + h*(1 + (2/pi)*np.arctan(n*(t_obs-t0)))

# %%
#MCMC modelo lineal


#modelo lineal con función
def mcmc_modelo_lineal(z, campo_m):
    a_walk = empty((0))
    b_walk = empty((0))
    like_walk = empty((0))
    a_walk = np.append(a_walk,np.random.random()*400 -200)
    b_walk = np.append(b_walk,np.random.random()*2 -1)
    
    #y inicial
    y_i = modelo_lineal(z, a_walk[0],b_walk[0])

    #areglo con la función de likelikelihood
    like_walk= np.append(like_walk,likelihood(campo_m,y_i))
    
    iteraciones = 200
    
    for i in range(iteraciones):
        a_prime = np.random.normal(a_walk[i], 0.1) 
        b_prime = np.random.normal(b_walk[i], 0.1)

        y_init = modelo_lineal(z, a_walk[i], b_walk[i])
        y_prime = modelo_lineal(z, a_prime, b_prime)
    
        like_prime = likelihood(campo_m, y_prime)
        like_init = likelihood(campo_m, y_init)
    
        alpha = like_prime-like_init #ya estan en logaritmicos
        if(alpha>=0.0):
            a_walk  = np.append(a_walk,a_prime)
            b_walk  = np.append(b_walk,b_prime)
            like_walk = np.append(like_walk, like_prime)
        else:
            beta = log(np.random.random())
            if(beta<=alpha):
                a_walk = np.append(a_walk,a_prime)
                b_walk = np.append(b_walk,b_prime)
                like_walk = np.append(like_walk, like_prime)
            else:
                a_walk = np.append(a_walk,a_walk[i])
                b_walk = np.append(b_walk,b_walk[i])
                like_walk = np.append(like_walk, like_init)
                
                
    return a_walk, b_walk, like_walk

# %%
#funcion del fit lineal

def fit_lineal(like, a, b):
    max_likelihood = np.argmax(like)
    best_a = a[max_likelihood]
    best_b = b[max_likelihood]
    best_campo = modelo_lineal(tiempo, best_a, best_b)
    
    return best_a, best_b, best_campo

# %%
#Probar funciones
a_walk, b_walk, like_walk=mcmc_modelo_lineal(tiempo, campo)

best_a, best_b, best_campo=fit_lineal(like_walk, a_walk, b_walk)

#print best_campo

plot (tiempo,best_campo)
scatter(tiempo,campo)
plt.show()

# %%
def mcmc_lineal_gauss(z, campo_m):
    
    c_walk = empty((0))
    d_walk = empty((0))
    sig_walk = empty((0))
    nu_walk = empty((0))
    like_walk2 = empty((0))
    c_walk = np.append(c_walk,np.random.random()*400 -200)
    d_walk = np.append(d_walk,np.random.random()*2 -1)
    sig_walk = np.append(sig_walk,35 +10*(np.random.random())) #genera numero sigma entre 355 y 45
    nu_walk = np.append(nu_walk,95 + 10*(np.random.random()))

    
    #y inicial
    yi_lg =lineal_gauss(z, c_walk[0],d_walk[0], sig_walk[0], nu_walk[0])

    #areglo con la función de likelikelihood
    like_walk2= np.append(like_walk2,likelihood_linealgauss(campo_m,yi_lg))

    iteraciones = 2000 #this is the number of iterations I want to make
    for i in range(iteraciones):
        c_prime = np.random.normal(c_walk[i], 0.1) 
        d_prime = np.random.normal(d_walk[i], 0.1)
        sig_prime = np.random.normal(sig_walk[i], 0.1) 
        nu_prime = np.random.normal(nu_walk[i], 0.1)

    
        y_init = lineal_gauss(z, c_walk[i], d_walk[i], sig_walk[i], nu_walk[i])
        y_prime = lineal_gauss(z, c_prime, d_prime, sig_prime, nu_prime)
    
        like_lg_prime = likelihood_linealgauss(campo_m, y_prime)
        like_lg_init = likelihood_linealgauss(campo_m, y_init)
    
        alpha_lg = like_lg_prime-like_lg_init
    
        if(alpha_lg>=0.0):
            c_walk  = append(c_walk,c_prime)
            d_walk  = append(d_walk,d_prime)
            sig_walk  = append(sig_walk,sig_prime)
            nu_walk  = append(nu_walk,nu_prime)

        
            like_walk2 = append(like_walk2, like_lg_prime)
        else:
            beta = log(np.random.random())
            if(beta<=alpha_lg):
                c_walk  = append(c_walk,c_prime)
                d_walk  = append(d_walk,d_prime)
                sig_walk  = append(sig_walk,sig_prime)
                nu_walk  = append(nu_walk,nu_prime)
                     
            
                like_walk2 = append(like_walk2, like_lg_prime)
            else:
                c_walk = append(c_walk,c_walk[i])
                d_walk = append(d_walk,d_walk[i])
                sig_walk = append(sig_walk,sig_walk[i])
                nu_walk = append(nu_walk,nu_walk[i])
                
                like_walk2 = append(like_walk2, like_lg_init)
                
    return c_walk, d_walk, sig_walk, nu_walk, like_walk2

# %%
def fit_linealgauss(like,c,d,sig,nu):
    max_likelihood = np.argmax(like)
    best_c = c[max_likelihood]
    best_d = d[max_likelihood]
    best_sig = sig[max_likelihood]
    best_nu = nu[max_likelihood]
    best_campo_lg = lineal_gauss(z, best_c, best_d, best_sig, best_nu)
    
    return best_campo_lg


c_walk, d_walk, sig_walk, nu_walk, like_walk2 = mcmc_lineal_gauss(tiempo, campo)
best_campolg=fit_linealgauss(like_walk2,c_walk,d_walk,sig_walk,nu_walk)


print best_campolg

plot(tiempo,best_campolg)
scatter(tiempo,campo)
plt.show()
# Out:
# [-17.66259227 -17.3665602  -17.07052813 -16.77449607 -16.478464
#  -16.18243193 -15.88639987 -15.5903678  -15.29433573 -14.99830367
#  -14.7022716  -14.40623953 -14.11020747 -13.8141754  -13.51814333
#  -13.22211127 -12.9260792  -12.63004713 -12.33401507 -12.037983
#  -11.74195093 -11.44591887 -11.1498868  -10.85385473 -10.55782267
#  -10.2617906   -9.96575854  -9.66972647  -9.3736944   -9.07766234
#   -8.78163027  -8.4855982   -8.18956614  -7.89353407  -7.597502
#   -7.30146994  -7.00543787  -6.7094058   -6.41337374  -6.11734167
#   -5.8213096   -5.52527754  -5.22924547  -4.9332134   -4.63718134
#   -4.34114927  -4.0451172   -3.74908514  -3.45305307  -3.157021
#   -2.86098894  -2.56495687  -2.2689248   -1.97289274  -1.67686067
#   -1.38082861  -1.08479654  -0.78876447  -0.49273241  -0.19670034
#    0.09933173   0.39536379   0.69139586   0.98742793   1.28345999
#    1.57949206   1.87552413   2.17155619   2.46758826   2.76362033
#    3.05965239   3.35568446   3.65171653   3.94774859   4.24378066
#    4.53981273   4.83584479   5.13187686   5.42790893   5.72394099
#    6.01997306   6.31600512   6.61203719   6.90806926   7.20410132
#    7.50013339   7.79616546   8.09219752   8.38822959   8.68426166
#    8.98029372   9.27632579   9.57235786   9.86838992  10.16442199
#   10.46045406  10.75648612  11.05251819  11.34855026  11.64458232
#   11.94061439  12.23664646  12.53267852  12.82871059  13.12474266
#   13.42077472  13.71680679  14.01283886  14.30887092  14.60490299
#   14.90093505  15.19696712  15.49299919  15.78903125  16.08506332
#   16.38109539  16.67712745  16.97315952  17.26919159  17.56522365
#   17.86125572  18.15728779  18.45331985  18.74935192  19.04538399
#   19.34141605  19.63744812  19.93348019  20.22951225  20.52554432
#   20.82157639  21.11760845  21.41364052  21.70967259  22.00570465
#   22.30173672  22.59776878  22.89380085  23.18983292  23.48586498
#   23.78189705  24.07792912  24.37396118  24.66999325  24.96602532
#   25.26205738  25.55808945  25.85412152  26.15015358  26.44618565
#   26.74221772  27.03824978  27.33428185  27.63031392  27.92634598
#   28.22237805  28.51841012  28.81444218  29.11047425  29.40650632
#   29.70253838  29.99857045  30.29460251  30.59063458  30.88666665
#   31.18269871  31.47873078  31.77476285  32.07079491  32.36682698
#   32.66285905  32.95889111  33.25492318  33.55095525  33.84698731
#   34.14301938  34.43905145  34.73508351  35.03111558  35.32714765
#   35.62317971  35.91921178  36.21524385  36.51127591  36.80730798
#   37.10334005  37.39937211  37.69540418  37.99143625  38.28746831
#   38.58350038  38.87953244  39.17556451  39.47159658  39.76762864
#   40.06366071  40.35969278  40.65572484  40.95175691  41.24778898
#   41.54382104  41.83985311  42.13588518  42.43191724  42.72794931
#   43.02398138  43.32001344]

# %%
#MCMC modelo lineal Paso


def mcmc_lineal_paso(z, campo_m):
    
    f_walk = empty((0))
    g_walk = empty((0))
    h_walk = empty((0))
    t0_walk = empty((0))
    n_walk = empty((0))
    like_walk3 = empty((0))

    f_walk = np.append(f_walk,np.random.random()*200 -50)
    g_walk = np.append(g_walk,np.random.random()*1 -0.5)
    h_walk = np.append(h_walk,np.random.random()*200 - 100)
    t0_walk = np.append(t0_walk,np.random.random()*300 +80)
    n_walk = np.append(n_walk,np.random.random()*100)

    #y inicial
    yi_lp =lineal_paso(z, f_walk[0], g_walk[0], h_walk[0], n_walk[0], t0_walk[0])

    #areglo con la función de likelikelihood
    like_walk3= np.append(like_walk3,likelihood_linealpaso(campo_m,yi_lp))

    iteraciones = 2000 #this is the number of iterations I want to make
    for i in range(iteraciones):
        f_prime = np.random.normal(f_walk[i], 0.1) 
        g_prime = np.random.normal(g_walk[i], 0.1)
        h_prime = np.random.normal(h_walk[i], 0.1) 
        n_prime = np.random.normal(n_walk[i], 0.1)
        t0_prime = np.random.normal(t0_walk[i], 0.1)

    
        y_init = lineal_paso(z, f_walk[i], g_walk[i], h_walk[i], n_walk[i], t0_walk[i])
        y_prime = lineal_paso(z, f_prime, g_prime, h_prime, n_prime, t0_prime)
    
        like_lp_prime = likelihood_linealpaso(campo_m, y_prime)
        like_lp_init = likelihood_linealpaso(campo_m, y_init)
    
        alpha_lp = like_lp_prime/like_lp_init
    
        if(alpha_lp>=0.0):
            f_walk  = append(f_walk,f_prime)
            g_walk  = append(g_walk,g_prime)
            h_walk  = append(h_walk,h_prime)
            n_walk  = append(n_walk,n_prime)
            t0_walk  = append(t0_walk,t0_prime)
    
        
            like_walk3 = append(like_walk3, like_lp_prime)
        else:
            beta =log(np.random.random())
            if(beta<=alpha_lp):
                f_walk  = append(f_walk,f_prime)
                g_walk  = append(g_walk,g_prime)
                h_walk  = append(h_walk,h_prime)
                n_walk  = append(n_walk,n_prime)
                t0_walk  = append(t0_walk,t0_prime)
        
                like_walk3 = append(like_walk3, like_lp_prime)
                     

            else:
                f_walk  = append(f_walk,f_walk[i])
                g_walk  = append(g_walk,g_walk[i])
                h_walk  = append(h_walk,h_walk[i])
                n_walk  = append(n_walk,n_walk[i])
                t0_walk  = append(t0_walk,t0_walk[i])
        
                like_walk3 = append(like_walk3, like_lp_init)
            
    return f_walk, g_walk, h_walk, n_walk, t0_walk, like_walk3

# %%
def fit_linealpaso(like, f, g, h, n, t0):
    max_likelihood = np.argmax(like)
    best_f = f[max_likelihood]
    best_g = g[max_likelihood]
    best_h = h[max_likelihood]
    best_n = n[max_likelihood]
    best_t0 = t0[max_likelihood]
    best_campo_lp = lineal_paso(tiempo, best_f, best_g, best_h, best_n, best_t0)
    return best_campo_lp


f_walk, g_walk, h_walk, n_walk, t0_walk, like_walk3 = mcmc_lineal_paso(tiempo, campo)
best_campo_lp=fit_linealpaso(like_walk3,f_walk,g_walk,h_walk,n_walk,t0_walk)

# %%
print best_campo_lp
# Out:
# [ 132.00904703  129.36088672  129.15718209  126.50902204  123.86086226
#   121.21270278  121.00899822  118.36083909  115.71268034  113.064522
#   112.86081753  110.21265971  107.56450242  104.91634574  104.71264141
#   102.06448548   99.41633038   96.76817622   96.5644721    93.91631914
#    91.2681675    88.62001744   88.41631366   85.76816566   83.12002003
#    82.50890989   82.30520654   82.10150322   81.89779991   81.69409662
#    81.49039335   81.2866901    81.08298687   80.87928367   80.67558048
#    80.47187731   80.26817417   80.06447105   79.86076795   79.65706487
#    79.45336182   79.24965879   79.04595578   78.8422528    78.63854984
#    78.43484691   78.23114401   78.02744113   77.82373828   77.62003546
#    77.41633267   77.2126299    77.00892717   76.80522446   76.60152179
#    76.39781915   76.19411654   75.99041396   75.78671142   75.58300891
#    75.37930643   75.17560399   74.97190159   74.76819922   74.5644969
#    74.36079461   74.15709236   73.95339015   73.74968799   73.54598587
#    73.34228379   73.13858175   72.93487976   72.73117782   72.52747593
#    72.32377409   72.12007229   71.91637055   71.71266886   71.50896723
#    71.30526565   71.10156413   70.89786267   70.69416127   70.49045993
#    70.28675865   70.08305744   69.87935629   69.67565522   69.47195421
#    69.26825328   69.06455242   68.86085164   68.65715094   68.45345032
#    68.24974978   68.04604933   67.84234897   67.6386487    67.43494852
#    67.23124844   67.02754846   66.82384859   66.62014882   66.41644916
#    66.21274961   66.00905018   65.80535087   65.60165169   65.39795264
#    65.19425372   64.99055493   64.7868563    64.5831578    64.37945947
#    64.17576129   63.97206328   63.76836544   63.56466777   63.36097029
#    63.157273     62.95357591   62.74987903   62.54618236   62.34248592
#    62.13878971   61.93509374   61.73139803   61.52770258   61.3240074
#    61.12031251   60.91661793   60.71292365   60.50922971   60.30553611
#    60.10184287   59.89815001   59.69445755   59.49076551   59.2870739
#    59.08338276   58.8796921    58.67600195   58.47231234   58.2686233
#    58.06493487   57.86124707   57.65755995   57.45387354   57.25018789
#    57.04650306   56.84281908   56.63913601   56.43545393   56.23177288
#    56.02809296   55.82441424   55.6207368    55.41706074   55.21338618
#    55.00971322   54.80604201   54.60237269   54.39870541   54.19504037
#    53.99137776   53.78771783   53.58406082   53.38040704   53.17675682
#    52.97311054   52.76946866   52.56583167   52.36220019   52.15857489
#    51.95495661   51.75134631   51.54774514   51.34415449   51.14057606
#    50.9370119    50.73346458   50.52993732   50.32643421   50.12296052
#    47.53652361   55.50218936   52.85597921   50.00476828   47.35689978
#    44.70891361   42.0563418    41.8526444    39.20456335   36.55646184
#    33.90834661   33.704645     31.0565195    28.40838713   25.76024957
#    25.5565465    22.90840467   20.26025974   17.61211232   17.40840858
#    14.76025898   12.11210773]

# %%
plot(tiempo,best_campo_lp)
scatter(tiempo,campo)
plt.show()
